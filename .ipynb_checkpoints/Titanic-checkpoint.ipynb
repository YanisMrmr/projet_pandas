# %% [markdown]
# # Titanic

# %%
import numpy as np
import pandas as pd

# Let's charge the csv
df = pd.read_csv("titanic.csv")
# Display the firest columns of the dataframe df
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          552         0       2
# 1          638         0       2
# 2          499         0       1
# 3          261         0       3
# 4          395         1       3
# 5          811         0       3
# 6          758         0       2
# 7          703         0       3
# 8          406         0       2
# 9          641         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                        Sharp, Mr. Percival James R    male  27.0      0
# 1                                Collyer, Mr. Harvey    male  31.0      1
# 2    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0      1
# 3                                  Smith, Mr. Thomas    male   NaN      0
# 4  Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengt...  female  24.0      0
# 5                             Alexander, Mr. William    male  26.0      0
# 6                           Bailey, Mr. Percy Andrew    male  18.0      0
# 7                              Barbara, Miss. Saiide  female  18.0      0
# 8                                 Gale, Mr. Shadrach    male  34.0      1
# 9                             Jensen, Mr. Hans Peder    male  20.0      0
#
#    Parch      Ticket      Fare    Cabin Embarked
# 0      0      244358   26.0000      NaN        S
# 1      1  C.A. 31921   26.2500      NaN        S
# 2      2      113781  151.5500  C22 C26        S
# 3      0      384461    7.7500      NaN        Q
# 4      2     PP 9549   16.7000       G6        S
# 5      0        3474    7.8875      NaN        S
# 6      0       29108   11.5000      NaN        S
# 7      1        2691   14.4542      NaN        C
# 8      0       28664   21.0000      NaN        S
# 9      0      350050    7.8542      NaN        S

# %%
# Here is the shape of the dataframe

print(f"It has {df.shape[0]} lines and {df.shape[1]} colums")
# Out:
# It has 891 lines and 12 colums

# %%
# We can select the grid we're interested in and have information about them

df[['Survived', 'Age', 'Fare']]
# Out:
#      Survived    Age      Fare
# 0           0  27.00   26.0000
# 1           0  31.00   26.2500
# 2           0  25.00  151.5500
# 3           0    NaN    7.7500
# 4           1  24.00   16.7000
# ..        ...    ...       ...
# 886         0  47.00   38.5000
# 887         1  30.00    9.5000
# 888         1  36.00  135.6333
# 889         0  22.00    7.7958
# 890         1   0.83   18.7500
#
# [891 rows x 3 columns]

# %%
df[['Survived', 'Age', 'Fare']].describe()
# Out:
#          Survived         Age        Fare
# count  891.000000  714.000000  891.000000
# mean     0.383838   29.699118   32.204208
# std      0.486592   14.526497   49.693429
# min      0.000000    0.420000    0.000000
# 25%      0.000000   20.125000    7.910400
# 50%      0.000000   28.000000   14.454200
# 75%      1.000000   38.000000   31.000000
# max      1.000000   80.000000  512.329200

# %%
# The columns of the dataframe are Series

type(df['Pclass'])
# Out:
# pandas.core.series.Series

# %%
# We can see, all the different classes we have
df['Pclass'].unique()
# Out:
# array([2, 1, 3])

# %%
# Creation of a mask
# To select only the females of the 1st class or of the 2nd class

mask = (df['Sex'] == 'female') & ((df['Pclass'] == 1) | (df['Pclass'] == 2))

# Or more simply

mask_eq = (df['Sex'] == 'female') & ~(df['Pclass'] == 3)

#Let's verify that it is the same thing
list(mask) == list(mask_eq)
# Out:
# True

# %%
# Let's apply this mask to our dataframe
df_female_1_or_2 = df[mask]
df_female_1_or_2.head(10)
# Out:
#     PassengerId  Survived  Pclass  \
# 2           499         0       1
# 13          755         1       2
# 16            2         1       1
# 18          338         1       1
# 23           53         1       1
# 27          718         1       2
# 38          505         1       1
# 39          514         1       1
# 40          376         1       1
# 42           10         1       2
#
#                                                  Name     Sex   Age  SibSp  \
# 2     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0      1
# 13                   Herman, Mrs. Samuel (Jane Laver)  female  48.0      1
# 16  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 18                    Burns, Miss. Elizabeth Margaret  female  41.0      0
# 23           Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# 27                Troutt, Miss. Edwina Celia "Winnie"  female  27.0      0
# 38                              Maioni, Miss. Roberta  female  16.0      0
# 39     Rothschild, Mrs. Martin (Elizabeth L. Barrett)  female  54.0      1
# 40              Meyer, Mrs. Edgar Joseph (Leila Saks)  female   NaN      1
# 42                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#     Parch    Ticket      Fare    Cabin Embarked
# 2       2    113781  151.5500  C22 C26        S
# 13      2    220845   65.0000      NaN        S
# 16      0  PC 17599   71.2833      C85        C
# 18      0     16966  134.5000      E40        C
# 23      0  PC 17572   76.7292      D33        C
# 27      0     34218   10.5000     E101        S
# 38      0    110152   86.5000      B79        S
# 39      0  PC 17603   59.4000      NaN        C
# 40      0  PC 17604   82.1708      NaN        C
# 42      0    237736   30.0708      NaN        C

# %%
#The mask can also be summed to obtain the number of women who match the mask.
mask.sum()
# Out:
# np.int64(170)

# %%
print(f"{100*mask.sum()/len(df)} % des passagers étaient des femmes en deuxième ou première classe")
# Out:
# 19.079685746352414 % des passagers étaient des femmes en deuxième ou première classe

# %%
# A large proportion of the 'cabins' are not filled in (NaN)
df.Cabin
# Out:
# 0          NaN
# 1          NaN
# 2      C22 C26
# 3          NaN
# 4           G6
#         ...
# 886        E63
# 887        NaN
# 888        C32
# 889        NaN
# 890        NaN
# Name: Cabin, Length: 891, dtype: object

# %%
# Create a mask that indicates where are the NaN with isna()
df.Cabin.isna()
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888    False
# 889     True
# 890     True
# Name: Cabin, Length: 891, dtype: bool

# %%
# We can supress the lines with the missing 'Cabin'
df_clear = df.dropna(subset = 'Cabin')
df_clear.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 2           499         0       1
# 4           395         1       3
# 16            2         1       1
# 18          338         1       1
# 20          545         0       1
#
#                                                  Name     Sex   Age  SibSp  \
# 2     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0      1
# 4   Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengt...  female  24.0      0
# 16  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 18                    Burns, Miss. Elizabeth Margaret  female  41.0      0
# 20                         Douglas, Mr. Walter Donald    male  50.0      1
#
#     Parch    Ticket      Fare    Cabin Embarked
# 2       2    113781  151.5500  C22 C26        S
# 4       2   PP 9549   16.7000       G6        S
# 16      0  PC 17599   71.2833      C85        C
# 18      0     16966  134.5000      E40        C
# 20      0  PC 17761  106.4250      C86        C

# %%
df['Age'].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
# To see how many missing values we have per lines
# axis = 1 to sum the columns, by default it sums the line
df.isna().sum(axis = 1)
# Out:
# 0      1
# 1      1
# 2      0
# 3      2
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    1
# Length: 891, dtype: int64

# %%
# The problem is that the passengers are not indexed correctly
# Let's change that
df.set_index('PassengerId', inplace = True)

# %%
df.isna().sum(axis = 1)
# The passenger whose ID is 261 misses 2 values
# Out:
# PassengerId
# 552    1
# 638    1
# 499    0
# 261    2
# 395    0
#       ..
# 463    0
# 287    1
# 326    0
# 396    1
# 832    1
# Length: 891, dtype: int64

# %%
# we can slice the dataframe with loc (for the index) and iloc (for the indice)

df_last = df.iloc[-10:, 0:2]
df_last #contains the 10 last lines and the columns of indice between 0 and 1 (the upper bound is not included for iloc)
# Out:
#              Survived  Pclass
# PassengerId
# 556                 0       1
# 236                 0       3
# 224                 0       3
# 598                 0       3
# 258                 1       1
# 463                 0       1
# 287                 1       3
# 326                 1       1
# 396                 0       3
# 832                 1       2

# %%
df_short_id = df.loc[499:395, 'Name']
df_short_id # The upper bound is incuded for loc
# Out:
# PassengerId
# 499      Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 261                                    Smith, Mr. Thomas
# 395    Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengt...
# Name: Name, dtype: object

# %%
# To know the name of the passenger 552
df.loc[552, 'Name']
# Out:
# 'Sharp, Mr. Percival James R'

# %% [markdown]
# # Group by
# We would like to know the rate of survival for each class and each sex

# %%
# We aggregate with a cartesian product

agg_df = df.groupby(['Pclass', 'Sex'])
agg_df.size()
# Out:
# Pclass  Sex
# 1       female     94
#         male      122
# 2       female     76
#         male      108
# 3       female    144
#         male      347
# dtype: int64

# %%
# The rate is obtained by taking the mean because 1 means survived and 0 means not survived

agg_df['Survived'].mean()
# Out:
# Pclass  Sex
# 1       female    0.968085
#         male      0.368852
# 2       female    0.921053
#         male      0.157407
# 3       female    0.500000
#         male      0.135447
# Name: Survived, dtype: float64

# %% [markdown]
# More than 96% of women of first class survived but less than 14% of men of third class survived.
